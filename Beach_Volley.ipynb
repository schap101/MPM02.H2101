# %% [markdown]
# <a href="https://colab.research.google.com/github/schap101/MPM02.H2101/blob/main/Beach_Volley.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# !pip install pandasql
import pandasql as ps

url = ['https://raw.githubusercontent.com/BigTimeStats/beach-volleyball/master/data/full_archive/full_archive.csv']       

df = pd.read_csv(url[0], index_col=None, header=0, encoding = "latin-1")

df.head(5)
# Out:
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26784 sha256=bff7c3316bbcddf42da9b4c0b10a7c1a6c704a5f97dea179ee4521fae780c675
#   Stored in directory: /root/.cache/pip/wheels/5c/4b/ec/41f4e116c8053c3654e2c2a47c62b4fca34cc67ef7b55deb7f
# Successfully built pandasql
# ...
#   circuit        tournament  ... l_p2_tot_blocks  l_p2_tot_digs
# 0     AVP  Huntington Beach  ...             1.0            NaN
# 1     AVP  Huntington Beach  ...             0.0            NaN
# 2     AVP  Huntington Beach  ...             0.0            NaN
# 3     AVP  Huntington Beach  ...             0.0            NaN
# 4     AVP  Huntington Beach  ...             1.0            NaN
#
# [5 rows x 65 columns]

# %%
df
# Out:
#       circuit        tournament  ... l_p2_tot_blocks  l_p2_tot_digs
# 0         AVP  Huntington Beach  ...             1.0            NaN
# 1         AVP  Huntington Beach  ...             0.0            NaN
# 2         AVP  Huntington Beach  ...             0.0            NaN
# 3         AVP  Huntington Beach  ...             0.0            NaN
# 4         AVP  Huntington Beach  ...             1.0            NaN
# ...       ...               ...  ...             ...            ...
# 81227    FIVB           Itapema  ...             NaN            NaN
# 81228    FIVB           Itapema  ...             NaN            NaN
# 81229    FIVB           Itapema  ...             NaN            NaN
# 81230    FIVB           Itapema  ...             NaN            NaN
# 81231    FIVB           Itapema  ...             NaN            NaN
#
# [81232 rows x 65 columns]

# %%
list(df.columns.values)
# Out:
# ['circuit',
#  'tournament',
#  'country',
#  'year',
#  'date',
#  'gender',
#  'match_num',
#  'w_player1',
#  'w_p1_birthdate',
#  'w_p1_age',
#  'w_p1_hgt',
#  'w_p1_country',
#  'w_player2',
#  'w_p2_birthdate',
#  'w_p2_age',
#  'w_p2_hgt',
#  'w_p2_country',
#  'w_rank',
#  'l_player1',
#  'l_p1_birthdate',
#  'l_p1_age',
#  'l_p1_hgt',
#  'l_p1_country',
#  'l_player2',
#  'l_p2_birthdate',
#  'l_p2_age',
#  'l_p2_hgt',
#  'l_p2_country',
#  'l_rank',
#  'score',
#  'duration',
#  'bracket',
#  'round',
#  'w_p1_tot_attacks',
#  'w_p1_tot_kills',
#  'w_p1_tot_errors',
#  'w_p1_tot_hitpct',
#  'w_p1_tot_aces',
#  'w_p1_tot_serve_errors',
#  'w_p1_tot_blocks',
#  'w_p1_tot_digs',
#  'w_p2_tot_attacks',
#  'w_p2_tot_kills',
#  'w_p2_tot_errors',
#  'w_p2_tot_hitpct',
#  'w_p2_tot_aces',
#  'w_p2_tot_serve_errors',
#  'w_p2_tot_blocks',
#  'w_p2_tot_digs',
#  'l_p1_tot_attacks',
#  'l_p1_tot_kills',
#  'l_p1_tot_errors',
#  'l_p1_tot_hitpct',
#  'l_p1_tot_aces',
# ...
